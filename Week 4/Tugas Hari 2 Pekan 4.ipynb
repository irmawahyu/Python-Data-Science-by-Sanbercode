# %% [markdown]
# <h1>Soal 1: Pemahaman Algoritma</h1>
#
# Jawab Pertanyaan di bawah ini dengan penyampaian bahasa sendiri!
#
# 1. Bagaimana proses algoritma KNN?
# 2. Jelaskan minimal 2 kekurangan dari algoritma KNN?

# %% [markdown]
# Jawab:

# %% [markdown]
# 1. Algoritma KNN :
#    - Menentukan jumlah tetangga terdekat
#    - Menghitung jarak antara data point baru dengan setiap poin menggunakan perhitungan euclidan distance. Kemudian mennetukan tetangga terdekat sesuai dengan jumlah tetangga terdekat yang telah ditentukan sebelumnya
#    - Melakukan voting atau menentukan kelompok mana yang memiliki lebih banyak tetangga terdekat dengan data point baru
# 2. Kekurangan KNN :
#    - Sangat sensitif terhadap data outlier/pencilan
#    - Algoritma KNN akan kebingungan jika jumlah tetangga terdekat pada setiap label berjumlah sama

# %% [markdown]
# <h1>Soal 2: Pengaplikasian Algoritma KNN</h1>
#
# - Buatlah model KNN
# - Training model tersebut kepada data X_train dengan hyperparameter kombinasi antara  2<= k <=20 dan weights bernilai 'uniform', dan 'distance'
# - Lakukan prediksi terhadap data X_test untuk model di setiap kombinasi k dan weights
# - Score dengan accuracy dari hasil prediksi terhadap data X_test untuk setiap kombinasi hyperparameter, masukan score tersebut ke dalam objek list dengan di groupkan berdasarkan jenis weights, sehingga di akhir kita punya variable misalkan list_uniform_score, dan list_distance_score
# - Plot kedua list tersebut dengan lineplot kedalam satu axis dan bandingkan hasilnya

# %%
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np

wine = load_wine()
df = pd.DataFrame(np.c_[wine['data'], wine['target']], columns= wine['feature_names'] + ['class'])

#Preprocessing data
X = df.drop('class', axis=1)
y = df['class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

# %%
from sklearn.neighbors import KNeighborsClassifier as knn
from sklearn.metrics import accuracy_score
from itertools import product

# %%
k = np.arange(2,21)
wg = ['uniform','distance']

def knn_model(n,w):
    knn_model = knn(n_neighbors=n, weights=w)
    knn_model.fit(X_train,y_train)
    y_predict = knn_model.predict(X_test)
    scores = accuracy_score(y_test, y_predict)
    return scores

Uniform_Scores = []
Distance_Scores = []
for n,w in product(k,wg):
    scores = knn_model(n,w)
    if w == 'uniform':
        Uniform_Scores.append(scores)
    else:
        Distance_Scores.append(scores)

# %%
Uniform_Scores
# Out:
# [0.6944444444444444,
#  0.8055555555555556,
#  0.7222222222222222,
#  0.6666666666666666,
#  0.6388888888888888,
#  0.75,
#  0.6388888888888888,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.7222222222222222,
#  0.6388888888888888,
#  0.6666666666666666,
#  0.6388888888888888,
#  0.6666666666666666,
#  0.6111111111111112,
#  0.6666666666666666,
#  0.6388888888888888,
#  0.6666666666666666,
#  0.6111111111111112]

# %%
Distance_Scores
# Out:
# [0.75,
#  0.8333333333333334,
#  0.7777777777777778,
#  0.75,
#  0.7222222222222222,
#  0.75,
#  0.6944444444444444,
#  0.7222222222222222,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,8))
ax.plot(k, Uniform_Scores, label='Uniform Scores', marker='x')
ax.plot(k, Distance_Scores, label='Distance Scores', marker='o')

fig.legend()
ax.set_xlabel('K-value')
ax.set_ylabel('Scores')
ax.set_title('Accuracy: Uniform Scores vs Distance Scores')
plt.show()

# %% [markdown]
# Contoh hasil yang di harapkan :
#
#
# ```
# Uniform Scores:
# [0.6944444444444444,
#  0.8055555555555556,
#  0.7222222222222222,
#  0.6666666666666666,
#  0.6388888888888888,
#  0.75,
#  0.6388888888888888,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.7222222222222222,
#  0.6388888888888888,
#  0.6666666666666666,
#  0.6388888888888888,
#  0.6666666666666666,
#  0.6111111111111112,
#  0.6666666666666666,
#  0.6388888888888888,
#  0.6666666666666666,
#  0.6111111111111112]
#
# Distance scores:
# [0.75,
#  0.8333333333333334,
#  0.7777777777777778,
#  0.75,
#  0.7222222222222222,
#  0.75,
#  0.6944444444444444,
#  0.7222222222222222,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.6944444444444444,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666]
# ```
#
#
#
#
#
#
# ![alt text](https://drive.google.com/uc?id=1pppy_BWQsg5tdgOBEU1GgiHSklLLoimt)

# %% [markdown]
# ---

# %% [markdown]
# <h1>Soal 3: Pengaplikasian Model Linear Regression</h1>
#
# Applikasikan model linear regresi kedalam data berikut. Kemudian tunjukan parameter koefesien dan intercept dari model tersebut.

# %%
import numpy as np

rng = np.random.RandomState(1)

X = 10 * rng.rand(50, 4)
y = np.array([  0.9826564 ,  49.40390035,  85.76013175,  29.17254633,
        11.270054  ,  61.53852735, -19.52503854,  10.10230867,
        82.03058206,  45.72660678,  82.09252575,  90.78872391,
        67.94178098,  39.97492762, 124.78866966,  85.24615819,
        85.68491086,  80.39481211,  14.54591581, 137.19722354,
        85.04063428,  94.76681927,  84.64289989,  38.76421156,
        47.33953927,  94.50853335,  77.3276567 ,  -9.77846805,
        61.13434468,  42.12124052,  26.65634335, 120.41593333,
       138.08132504, 103.33745675, 145.64447692,  19.54777986,
        87.40631024, 111.47327389,  95.94874761, 146.34817502,
       118.10333528,  56.85956484, 108.57660235, 114.30790247,
        40.27107041,  73.83871008,  45.52217182,  -7.57752547,
       147.81772162, 139.40285349])

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression(fit_intercept = True)

lr_model.fit(X, y)

ytrain = lr_model.predict(X)
ytrain
# Out:
# array([  0.9826564 ,  49.40390035,  85.76013175,  29.17254633,
#         11.270054  ,  61.53852735, -19.52503854,  10.10230867,
#         82.03058206,  45.72660678,  82.09252575,  90.78872391,
#         67.94178098,  39.97492762, 124.78866966,  85.24615819,
#         85.68491086,  80.39481211,  14.54591581, 137.19722354,
#         85.04063428,  94.76681927,  84.64289989,  38.76421156,
#         47.33953927,  94.50853335,  77.32765671,  -9.77846804,
#         61.13434468,  42.12124053,  26.65634335, 120.41593333,
#        138.08132504, 103.33745675, 145.64447692,  19.54777986,
#         87.40631024, 111.4732739 ,  95.94874762, 146.34817502,
#        118.10333528,  56.85956484, 108.57660235, 114.30790247,
#         40.27107041,  73.83871008,  45.52217182,  -7.57752547,
#        147.81772162, 139.40285349])

# %%
lr_model.coef_
# Out:
# array([ 1.5, -5. ,  9. , 10. ])

# %%
lr_model.intercept_
# Out:
# 0.5000000016247412
